# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 2000)

# %% [markdown]
# ## New York
#
# New York data download from here: https://data.ny.gov/Transportation/Vehicle-Snowmobile-and-Boat-Registrations/w4pv-hbkt

# %%
ny_reg = pd.read_csv('../data/ny/20210111_ny_vehicle_registrations.csv')

ny_reg['reg_valid_date'] = pd.to_datetime(ny_reg['Reg Valid Date'])
ny_reg['reg_exp_date'] = pd.to_datetime(ny_reg['Reg Expiration Date'])

ny_reg['reg_valid_month'] = ny_reg['reg_valid_date'].dt.month
ny_reg['reg_valid_year'] = ny_reg['reg_valid_date'].dt.year

ny_veh = ny_reg.loc[ny_reg['Record Type'] == 'VEH']
# Out:
# /Users/akanik/.local/share/virtualenvs/car-free-cities-Oj_SXpK8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
ny_veh.dtypes
# Out:
# Record Type                     object
# VIN                             object
# Registration Class              object
# City                            object
# State                           object
# Zip                              int64
# County                          object
# Model Year                     float64
# Make                            object
# Body Type                       object
# Fuel Type                       object
# Unladen Weight                 float64
# Maximum Gross Weight           float64
# Passengers                     float64
# Reg Valid Date                  object
# Reg Expiration Date             object
# Color                           object
# Scofflaw Indicator              object
# Suspension Indicator            object
# Revocation Indicator            object
# reg_valid_date          datetime64[ns]
# reg_exp_date            datetime64[ns]
# reg_valid_month                  int64
# reg_valid_year                   int64
# dtype: object

# %%
ny_veh.columns[nyc_reg.isna().any()].tolist()
# Out:
# ['VIN',
#  'Model Year',
#  'Make',
#  'Fuel Type',
#  'Unladen Weight',
#  'Maximum Gross Weight',
#  'Passengers',
#  'Reg Expiration Date',
#  'Color',
#  'reg_exp_date']

# %%
ny_veh.head()
# Out:
#   Record Type                VIN Registration Class           City State  \
# 0         VEH  5NPEC4AC9BH056988                PAS          DEPEW    NY
# 1         VEH  5N1AR2MM2EC732280                PAS      GLENVILLE    NY
# 2         VEH  5N1AR2MM2EC732277                PAS     MASSAPEQUA    NY
# 3         VEH  5N1AR2MM2EC731100                PAS  STATEN ISLAND    NY
# 4         VEH  5N1AR2MM2EC730951                PAS        MANLIUS    NY
#
#      Zip       County  Model Year   Make Body Type Fuel Type  Unladen Weight  \
# 0  14043         ERIE      2011.0  HYUND      4DSD       GAS          3316.0
# 1  12302  SCHENECTADY      2014.0  NISSA      SUBN       GAS          4262.0
# 2  11762       NASSAU      2014.0  NISSA      SUBN       GAS          4262.0
# 3  10305     RICHMOND      2014.0  NISSA      SUBN       GAS          4200.0
# 4  13104     ONONDAGA      2014.0  NISSA      SUBN       GAS          4384.0
#
#    Maximum Gross Weight  Passengers Reg Valid Date Reg Expiration Date Color  \
# 0                   NaN         NaN     09/24/2020          09/23/2022    GY
# 1                   NaN         NaN     05/06/2019          05/15/2021    GY
# 2                   NaN         NaN     06/11/2019          08/29/2021    BK
# 3                   NaN         NaN     09/18/2020          09/12/2022    GY
# 4                   NaN         NaN     10/20/2020          11/24/2022    RD
#
#   Scofflaw Indicator Suspension Indicator Revocation Indicator reg_valid_date  \
# 0                  N                    N                    N     2020-09-24
# 1                  N                    N                    N     2019-05-06
# 2                  N                    N                    N     2019-06-11
# 3                  N                    N                    N     2020-09-18
# 4                  N                    N                    N     2020-10-20
#
#   reg_exp_date  reg_valid_month  reg_valid_year
# 0   2022-09-23                9            2020
# 1   2021-05-15                5            2019
# 2   2021-08-29                6            2019
# 3   2022-09-12                9            2020
# 4   2022-11-24               10            2020

# %%
ny_veh['reg_valid_date'].max()
# Out:
# Timestamp('2021-02-01 00:00:00')

# %%
len(ny_veh)
# Out:
# 10518300

# %%
ny_veh['State'].unique()
# Out:
# array(['NY', 'FL', 'MD', 'NJ', 'MA', 'NT', 'NC', 'TN', 'AZ', 'CT', 'VA',
#        'NV', 'CO', 'CA', 'SC', 'WA', 'VT', 'PA', 'OK', 'IL', 'KY', 'S',
#        'OR', 'OH', 'IA', 'LA', 'TX', 'MN', 'GA', 'NU', 'SD', 'AP', 'IN',
#        'DE', 'ON', 'RI', 'WI', 'KS', 'AK', 'NE', 'NM', 'DC', 'ME', 'AL',
#        'WV', 'MI', 'UT', 'WY', 'NH', 'GS', 'MO', 'Y', 'HI', 'OT', 'AE',
#        'AR', 'ND', 'MS', 'DR', 'MT', 'PR', 'GU', 'ID', 'US', 'QC', 'AA',
#        'RK', 'AN', 'AY', 'YY', 'YT', 'YH', 'VI', 'NS', 'U', 'ST', 'NB',
#        'PK', 'TA', 'BC', 'MY'], dtype=object)

# %%
ny_veh.groupby('State')['Record Type'].count()
# Out:
# State
# AA          10
# AE          12
# AK          27
# AL         673
# AN           2
# AP          13
# AR         185
# AY           2
# AZ         416
# BC           1
# CA        1735
# CO         357
# CT        3522
# DC         112
# DE         224
# DR           1
# FL        4828
# GA        6455
# GS           2
# GU           4
# HI          47
# IA          34
# ID          12
# IL       15081
# IN        3736
# KS         111
# KY         128
# LA          95
# MA        1661
# MD       14093
# ME         137
# MI         407
# MN         508
# MO         537
# MS          31
# MT          69
# MY           1
# NB           2
# NC         952
# ND          21
# NE          70
# NH         514
# NJ       29617
# NM          77
# NS           3
# NT         305
# NU          97
# NV         173
# NY    10386724
# OH        1212
# OK       25263
# ON          19
# OR          85
# OT          11
# PA        3565
# PK           1
# PR          14
# QC           2
# RI         173
# RK           1
# S            1
# SC         424
# SD          27
# ST           1
# TA           1
# TN        1069
# TX        7811
# U            1
# US          13
# UT         124
# VA         898
# VI           2
# VT         282
# WA         336
# WI        3025
# WV          84
# WY          23
# Y            5
# YH           1
# YT           1
# YY           1
# Name: Record Type, dtype: int64

# %%
ny_only = ny_veh.loc[ny_veh['State'] == 'NY'].sort_values('City')
list(ny_only.City.unique())
# Out:
# ['-',
#  '0CEANSIDE',
#  '14E BRONX',
#  '201 E 2ND JMST',
#  '87',
#  'A BABYLON',
#  'AAMHERST',
#  'AASTORIA',
#  'ABANY',
#  'ABERTSON',
#  'ABINGTON PL',
#  'ABLANY',
#  'ABLION',
#  'ABOOKLYN',
#  'ABRDONIA',
#  'ABURN',
#  'ACCORD',
#  'ACCORD NY',
#  'ACCPRD',
#  'ACEAT NECK',
#  'ACENX',
#  'ACKSON HEIGHTS',
#  'ACMDEN',
#  'ACORD',
#  'ACRA',
#  'ACRAM',
#  'ACREDE',
#  'ADAM',
#  'ADAM CENTER',
#  'ADAMS',
#  'ADAMS BASIN',
#  'ADAMS CANTER',
#  'ADAMS CE NTER',
#  'ADAMS CENTER',
#  'ADAMS CNTR',
#  'ADAMS CT',
#  'ADAMS CTR',
#  'ADDDISON',
#  'ADDESLEIGH PAR',
#  'ADDESLEIGH PK',
#  'ADDISIEIGH PK',
#  'ADDISLEIGH',
#  'ADDISLEIGH PAR',
#  'ADDISLEIGH PK',
#  'ADDISLEIGH PRK',
#  'ADDISON',
#  'ADDISSON',
#  'ADDSION',
#  'ADIRNDACK',
#  'ADIRONACK',
#  'ADIRONDACK',
#  'ADIRONDICK',
#  'ADIRONDOCK',
#  'ADISON',
#  'ADLER CREEK',
#  'ADLFRED',
#  'ADMAS',
#  'ADNASTOTA',
#  'ADNE ISLAND',
#  'ADNES',
#  'ADOW',
#  'ADOWS',
#  'ADRCELLUS',
#  'ADRCHASE',
#  'ADRIONDACK',
#  'ADRNING',
#  'ADST CHAZY',
#  'ADTORIA',
#  'AELEGANY',
#  'AEVERNE',
#  'AEW YORK',
#  'AFLRED',
#  'AFLRED STATION',
#  'AFRED STATION',
#  'AFTON',
#  'AFTRON',
#  'AGRYLE',
#  'AGUE BOGUE',
#  'AGUEBOGUE',
#  'AHERST',
#  'AHKWESAHSNE',
#  'AHMERST',
#  'AHMHERST',
#  'AHTENS',
#  'AHUPPAGUE',
#  'AIMRONT',
#  'AINVIEW',
#  'AIRMONT',
#  'AIRMORT',
#  'AIRMOUNT',
#  'AIUBURN',
#  'AJAMESPORT',
#  'AK RONKONKOMA',
#  'AKBANY',
#  'AKE',
#  'AKE VIEW',
#  'AKON',
#  'AKRON',
#  'AKRPORT',
#  'AKVILLE',
#  'AKWASASNE',
#  'AKWESANE',
#  'AKWESASNE',
#  'AKWESASNE IND',
#  'AKWESSANE',
#  'AKWSASNE',
#  'AL BANY',
#  'AL HWYOK',
#  'ALABAMA',
#  'ALABANY',
#  'ALABNY',
#  'ALALAPHIN',
#  'ALAMONT',
#  'ALANTIC BEACH',
#  'ALANY',
#  'ALATAMONT',
#  'ALBA',
#  'ALBABY',
#  'ALBALY',
#  'ALBAN',
#  'ALBANAY',
#  'ALBANS',
#  'ALBANTY',
#  'ALBANUY',
#  'ALBANY',
#  'ALBANY NY',
#  'ALBANYA',
#  'ALBANYNY',
#  'ALBARTSON',
#  'ALBAY',
#  'ALBEARTSTON',
#  'ALBEERTSON',
#  'ALBERSTON',
#  'ALBERSTSON',
#  'ALBERT',
#  'ALBERTON',
#  'ALBERTSON',
#  'ALBERTSON DOWN',
#  'ALBERTSON LI',
#  'ALBERTSTON',
#  'ALBETSON',
#  'ALBIEN',
#  'ALBIN',
#  'ALBINS',
#  'ALBIOIN',
#  'ALBION',
#  'ALBNAY',
#  'ALBNY',
#  'ALBON',
#  'ALBRTSON',
#  'ALBURGH',
#  'ALBURN',
#  'ALCOVE',
#  'ALDA CREEK',
#  'ALDEN',
#  'ALDEN MANOR',
#  'ALDENNY',
#  'ALDER CREEK',
#  'ALDER CRK',
#  'ALDERCREEK',
#  'ALDNE',
#  'ALDON',
#  'ALEN',
#  'ALEX',
#  'ALEX BAY',
#  'ALEXANDER',
#  'ALEXANDERIA BY',
#  'ALEXANDIA BAY',
#  'ALEXANDIRA BAY',
#  'ALEXANDRA BAY',
#  'ALEXANDREA BAY',
#  'ALEXANDRIA',
#  'ALEXANDRIA BA',
#  'ALEXANDRIA BAY',
#  'ALEXANDRIA BY',
#  'ALEXANDRIE BAY',
#  'ALEXANER',
#  'ALEXANRIA BAY',
#  'ALEXNRRIA BAY',
#  'ALFRED',
#  'ALFRED DTA',
#  'ALFRED ST',
#  'ALFRED STA',
#  'ALFRED STAT',
#  'ALFRED STATION',
#  'ALGELICA',
#  'ALIBON',
#  'ALIFTON PARK',
#  'ALLE',
#  'ALLEGANY',
#  'ALLEGARY',
#  'ALLEGHANY',
#  'ALLEGHENY',
#  'ALLEGNY',
#  'ALLENTOWN',
#  'ALLERTON',
#  'ALLEY',
#  'ALLLEGANY',
#  'ALMA',
#  'ALMHERST',
#  'ALMND',
#  'ALMOND',
#  'ALMONT',
#  'ALMOSND',
#  'ALO',
#  'ALPAUS',
#  'ALPINE',
#  'ALPLASSO',
#  'ALPLAUS',
#  'ALPLUAS',
#  'ALTALMONT',
#  'ALTAMONT',
#  'ALTAMONTE',
#  'ALTAMONY',
#  'ALTAMOUNT',
#  'ALTANTIC BEACH',
#  'ALTENA',
#  'ALTIMAR',
#  'ALTLANTIC BCH',
#  'ALTLANTIC BEAC',
#  'ALTMANT',
#  'ALTMAR',
#  'ALTMONT',
#  'ALTO',
#  'ALTON',
#  'ALTONA',
#  'ALTONT',
#  'ALUSHING',
#  'ALVERNE',
#  'AM ITYVILLE',
#  'AMAEALK',
#  'AMAGAMSETT',
#  'AMAGANESTT',
#  'AMAGANSET',
#  'AMAGANSETT',
#  'AMAGANSSETT',
#  'AMAGANSTT',
#  'AMAGASETT',
#  'AMAGASNSETT',
#  'AMAGAWSETT',
#  'AMAGENSETT',
#  'AMAGNSETT',
#  'AMAICA',
#  'AMANGANSETT',
#  'AMANGASETT',
#  'AMARLBORO',
#  'AMASTERDAM',
#  'AMAWAK',
#  'AMAWAL',
#  'AMAWALK',
#  'AMAWLAK',
#  'AMCRAM',
#  'AMCRAMDALE',
#  'AMDSTERDAM',
#  'AMEHRST',
#  'AMEINA',
#  'AMENA',
#  'AMENIA',
#  'AMENIC',
#  'AMENICA',
#  'AMENIS',
#  'AMENISA',
#  'AMERST',
#  'AMERSTERDAM',
#  'AMES',
#  'AMETTYVILLE',
#  'AMFERST',
#  'AMGANASETT',
#  'AMGANSETT',
#  'AMGOLA',
#  'AMH',
#  'AMHEARST',
#  'AMHEERST',
#  'AMHEREST',
#  'AMHERS',
#  'AMHERSDT',
#  'AMHERST',
#  'AMHERST NY',
#  'AMHERSTE',
#  'AMHERT',
#  'AMHERTS',
#  'AMHESRT',
#  'AMHEST',
#  'AMHREST',
#  'AMHRST',
#  'AMHUREST',
#  'AMHURST',
#  'AMIITYVILLE',
#  'AMINTYVILLE',
#  'AMITGVILLE',
#  'AMITHTOWN',
#  'AMITHVILLE',
#  'AMITIVILLE',
#  'AMITIYVILLE',
#  'AMITTYVILLE',
#  'AMITUVILLE',
#  'AMITVILLE',
#  'AMITVYLLE',
#  'AMITY',
#  'AMITY HABOR',
#  'AMITY HAR',
#  'AMITY HARBOR',
#  'AMITY HARBOUR',
#  'AMITY HBR',
#  'AMITY HRBR',
#  'AMITY VILLE',
#  'AMITYHARBOR',
#  'AMITYILLE',
#  'AMITYUVILLE',
#  'AMITYV HARBOR',
#  'AMITYVIILE',
#  'AMITYVILE',
#  'AMITYVILL',
#  'AMITYVILL HRBR',
#  'AMITYVILLE',
#  'AMITYVILLE HAR',
#  'AMITYVILLE HBR',
#  'AMITYVILLLE',
#  'AMITYVLLE',
#  'AMITYVVILLE',
#  'AMITYWILLE',
#  'AMITYYVILLE',
#  'AMIYTVILLE',
#  'AMIYVILLE',
#  'AMMHERST',
#  'AMMITYVILLE',
#  'AMNLIUS',
#  'AMONK',
#  'AMS',
#  'AMSERDAM',
#  'AMSGANSETT',
#  'AMSTEDAM',
#  'AMSTERADAM',
#  'AMSTERAM',
#  'AMSTERDA',
#  'AMSTERDAM',
#  'AMSTERDAM AVE',
#  'AMSTERDAM NY',
#  'AMSTERDAMN',
#  'AMSTERDAN',
#  'AMSTERDCAM',
#  'AMSTERDM',
#  'AMSTEREDAM',
#  'AMSTESDAM',
#  'AMSTRDAM',
#  'AMSTREDAM',
#  'AMTERDAM',
#  'AMTITYVILLE',
#  'AMTIYVILLE',
#  'AMTYVILLE',
#  'AMUTYVILLE',
#  'AMWALK',
#  'AMYTILLE',
#  'AMYTIVILLE',
#  'ANADA',
#  'ANAGANETT',
#  'ANANDL ON HDSN',
#  'ANBURN',
#  'ANCHOR',
#  'ANCRA',
#  'ANCRAM',
#  'ANCRAMDALE',
#  'ANCRAMDALE RD',
#  'ANCRANDALE',
#  'ANCRMDALE',
#  'ANDES',
#  'ANDING',
#  'ANDOVER',
#  'ANDRAM',
#  'ANEERO',
#  'ANGELIA',
#  'ANGELICA',
#  'ANGELINA',
#  'ANGLA',
#  'ANGLEICA',
#  'ANGLOA',
#  'ANGOLA',
#  'ANGOLA VIL',
#  'ANGOLEA',
#  'ANGOLO',
#  'ANHERST',
#  'ANITYVILLE',
#  'ANNADALE',
#  'ANNADALE HUDSN',
#  'ANNADALE N HDS',
#  'ANNADALE ON HD',
#  'ANNADALEONHDSN',
#  'ANNADALEONHUDS',
#  'ANNADL ON HUD',
#  'ANNADLE N HDSN',
#  'ANNADLE ON HUD',
#  'ANNANDAL ON HU',
#  'ANNANDALE',
#  'ANNANDALE HDSN',
#  'ANNANDALE HUD',
#  'ANNANDALE ON H',
#  'ANNANDALENHDSN',
#  'ANNANDALEONHDS',
#  'ANNANDALEONHUD',
#  'ANNANDL ON HDS',
#  'ANNANDL ON HUD',
#  'ANNANDLE ON HU',
#  'ANNDL ON HDSN',
#  'ANNDL ON HUDSN',
#  'ANNDLE ON HUDS',
#  'ANNNDALE',
#  'ANOGLA',
#  'ANSONIA STA',
#  'ANTHROP',
#  'ANTIA',
#  'ANTWERP',
#  'ANWTERP',
#  'AORNELL',
#  'AP1-0NEWYORK',
#  'APAALCHIN',
#  'APAHDIN',
#  'APALACHIA',
#  'APALACHILN',
#  'APALACHIN',
#  'APALACHIN NY',
#  'APALACHN',
#  'APALACIN',
#  'APALAN',
#  'APALCAHIN',
#  'APALCHIN',
#  'APAPACHIN',
#  'APHANK',
#  'APLACHIN',
#  'APLAUS',
#  'APLETON',
#  'APPALACHIN',
#  'APPLACHIN',
#  'APPLELETON',
#  'APPLETON',
#  'APPLLETON',
#  'APPLTON',
#  'APRING VALLEY',
#  'APT A',
#  'APT DSTER',
#  'APT DTSKILL',
#  'APULIA ST',
#  'APULIA STA',
#  'APULIA STATION',
#  'AQEBOGUE',
#  'AQUABOGUE',
#  'AQUBOGUE',
#  'AQUEBOGUE',
#  'AQUEBOGUQE',
#  'AQUEBOQUE',
#  'AQUEBOUE',
#  'AQUEBOUGE',
#  'AQUEBOUGUE',
#  'AQUEGOGUE',
#  'AQUEGUE',
#  'AQUEOGUE',
#  'AQUESBOGUE',
#  'AQUIRE',
#  'ARACADE',
#  'ARAMONK',
#  'ARBERNE',
#  'ARBYLE',
#  'ARCA',
#  'ARCADA',
#  'ARCADE',
#  'ARCADIA',
#  'ARCADO',
#  'ARCADW',
#  'ARCARDE',
#  'ARCRA',
#  'ARCRAM',
#  'ARDEN',
#  'ARDENS',
#  'ARDLEY',
#  'ARDLSEY',
#  'ARDSELY',
#  'ARDSEY',
#  'ARDSLEY',
#  'ARDSLEY HDSN',
#  'ARDSLEY HUDSON',
#  'ARDSLEY N HDSN',
#  'ARDSLEY ON HDS',
#  'ARDSLEY ON HUD',
#  'ARDSLEY ON THE',
#  'ARDSLEY ONHDSN',
#  'ARDSLEYL',
#  'ARDSLEYONHUDSO',
#  'ARDSLY HUDSON',
#  'ARDSLY ON HDSN',
#  'ARDSLY ON HUSN',
#  'ARDSLY/HUDSON',
#  'ARDSSSLEY',
#  'AREVERN',
#  'ARGLE',
#  'ARGLES',
#  'ARGLYE',
#  'ARGUKE',
#  'ARGUL',
#  'ARGULE',
#  'ARGYEL',
#  'ARGYLE',
#  'ARHPORT',
#  'ARK PORT',
#  'ARKMONK',
#  'ARKON',
#  'ARKORT',
#  'ARKPORT',
#  'ARKVILLE',
#  'ARKWARD',
#  'ARLENE',
#  'ARLINGTON',
#  'ARMANK',
#  'ARMARK',
#  'ARMEL',
#  'ARMENIA',
#  'ARMINGDALE',
#  'ARMNK',
#  'ARMNOK',
#  'ARMOK',
#  'ARMONK',
#  'ARMONK NY',
#  'ARMONK4',
#  'ARMONKE',
#  'ARMONT',
#  'ARONX',
#  'AROOKLYN',
#  'AROSLEY',
#  'ARSDLEY',
#  'ARSLEY',
#  'ARSLEY ON HDSO',
#  'ARSSLEY',
#  'ARTMONT',
#  'ARUERNE',
#  'ARVEME',
#  'ARVENE',
#  'ARVERENE',
#  'ARVERN',
#  'ARVERNE',
#  'ARVERNE NY',
#  'ARVERNT',
#  'ARVERVE',
#  'ARVRENE',
#  'ARYGLE',
#  'ASATORIA',
#  'ASDSLEY',
#  'ASDTORIA',
#  'ASHARDKEN',
#  'ASHAROKEN',
#  'ASHAROKEN BCH',
#  'ASHEROKEN',
#  'ASHEVILLE',
#  'ASHFORD',
#  'ASHFORD W VALL',
#  'ASHLAND',
#  'ASHLND',
#  'ASHOKAN',
#  'ASHONIE',
#  'ASHROKEN',
#  'ASHVILLE',
#  'ASHVILLE NY',
#  'ASHVLLE',
#  'ASLAND',
#  'ASMTERDAM',
#  'ASORIA',
#  'ASOTRIA',
#  'ASRORIA',
#  'ASSINING',
#  'AST MEADOW',
#  'ASTERDAM',
#  'ASTERIA',
#  'ASTIORIA',
#  'ASTOCIA',
#  'ASTOIA',
#  'ASTONIA',
#  'ASTOR',
#  'ASTORA',
#  'ASTORAI',
#  'ASTORE',
#  'ASTORI',
#  'ASTORIA',
#  'ASTORIA HEIGHT',
#  'ASTORIA HGTS',
#  'ASTORIA HTS',
#  'ASTORIA LI',
#  'ASTORIA LIC',
#  'ASTORIA NY',
#  'ASTORIA QUEENS',
#  'ASTORICA',
#  'ASTORID',
#  'ASTORIO',
#  'ASTORIS',
#  'ASTOSIA',
#  'ASTOTIA',
#  'ASTRIA',
#  'ASTROIA',
#  'ASVILLE',
#  'AT ALBANS',
#  'AT TRUMP PLACE',
#  'ATAMONT',
#  'ATERLING',
#  'ATERVLIET',
#  'ATHAMA',
#  'ATHEN',
#  'ATHENS',
#  'ATHES',
#  'ATHOL',
#  'ATHOL SPRINGS',
#  'ATHOL SPRNGS',
#  'ATICA',
#  'ATIICA',
#  'ATL BEACH',
#  'ATLAMONT',
#  'ATLANCIT BEACH',
#  'ATLANCTIC BCH',
#  'ATLANTA',
#  'ATLANTA BEACH',
#  'ATLANTIC BAECH',
#  'ATLANTIC BAY',
#  'ATLANTIC BCH',
#  'ATLANTIC BEAC',
#  'ATLANTIC BEACH',
#  'ATLANTIC BLVD',
#  'ATLNATIC BEACH',
#  'ATLNTC BCH EST',
#  'ATLNTC BEACH',
#  'ATLNTIC BH EST',
#  'ATNWERP',
#  'ATONAH',
#  'ATORIA',
#  'ATTICA',
#  'AU ABLE FORKS',
#  'AU SAB FOR',
#  'AU SABLE',
#  'AU SABLE FOLKS',
#  'AU SABLE FORKS',
#  'AU SABLE FRKS',
#  'AU SBALE FORKS',
#  'AUBRN',
#  'AUBRUN',
#  'AUBUARN',
#  'AUBUR',
#  'AUBURA',
#  'AUBURDALE',
#  'AUBURN',
#  'AUBURN DALE',
#  'AUBURNDALE',
#  'AUGOLA',
#  'AUGUS',
#  'AUGUSTA',
#  'AUILDERLAND',
#  'AUOGUE',
#  'AURBANDALE',
#  'AURBURN',
#  'AURELIUS',
#  'AURELTON',
#  'AURO',
#  'AURORA',
#  'AUROROA',
#  'AUSABLE',
#  'AUSABLE CHASM',
#  'AUSABLE FOKKS',
#  'AUSABLE FORK',
#  'AUSABLE FORKS',
#  'AUSABLE FRKS',
#  'AUSABLE FROKS',
#  'AUSABLEFORKS',
#  'AUSSABLE FORKS',
#  'AUSTERLITZ',
#  'AUSTERTITZ',
#  'AUSTORIA',
#  'AUTERLITZ',
#  'AUUBRN',
#  'AUURN',
#  'AUVERA',
#  'AVA',
#  'AVACA',
#  'AVDSLEY',
#  'AVE',
#  'AVE YORK',
#  'AVEILL PARK',
#  'AVER PARK',
#  'AVERENE',
#  'AVERID PK',
#  'AVERIL PARK',
#  'AVERILL',
#  'AVERILL APRK',
#  'AVERILL PARK',
#  'AVERILL PARK N',
#  'AVERILL PK',
#  'AVERILL PRK',
#  'AVERILL PSRK',
#  'AVERILL WAY',
#  'AVERILLE PARK',
#  'AVERILLPARK',
#  'AVERNE',
#  'AVION',
#  'AVOCA',
#  'AVOCO',
#  'AVOLA',
#  'AVON',
#  'AVON NY',
#  'AVORA',
#  'AVRILL PARK',
#  'AWAWALK',
#  'AWKESASNE',
#  'AWKWESASNE',
#  'AYCHARD PARK',
#  'AYCTOR',
#  'AYLTON',
#  'AYVILLE',
#  'B FER',
#  'BA SHORE',
#  'BAAYSIDE',
#  'BABAYLON',
#  'BABLON',
#  'BABLYON',
#  'BABRIELS',
#  'BABTLON',
#  'BABYLON',
#  'BABYLON VIL',
#  'BABYLON VILAGE',
#  'BABYLON VILL',
#  'BABYLON VILLAG',
#  'BABYLON VILLG',
#  'BABYLON VILLGE',
#  'BABYLON VL GE',
#  'BABYLON VLG',
#  'BABYLON VLGE',
#  'BABYLON VLLAG',
#  'BABYLON VLLAGE',
#  'BABYLON VLLG',
#  'BABYLON VLLGE',
#  'BABYLONG',
#  'BABYLONVILLAG',
#  'BABYON',
#  'BACHANAN',
#  'BADLWIN',
#  'BADLWINSVILLE',
#  'BADWIN',
#  'BADWINSVILLE',
#  'BAECON',
#  'BAH SHORE',
#  'BAHEMIA',
#  'BAIDWIN',
#  'BAIDWINSVILLE',
#  'BAINBIDGE',
#  'BAINBIRDGE',
#  'BAINBRAIGE',
#  'BAINBRDIGE',
#  'BAINBRIDE',
#  'BAINBRIDG',
#  'BAINBRIDGE',
#  'BAINBRIGE',
#  'BAINRIDGE',
#  'BAINTING HOLLO',
#  'BAIRBRIDGE',
#  'BAISLEY PARK',
#  'BAISLEY PK',
#  'BAITIN HOLLOW',
#  'BAITIND HOLLOW',
#  'BAITINE HOLL',
#  'BAITING',
#  'BAITING HALLOW',
#  'BAITING HLLLOW',
#  'BAITING HLLW',
#  'BAITING HLW',
#  'BAITING HOLLO',
#  'BAITING HOLLOW',
#  'BAITING HOLLW',
#  'BAITING HOLOW',
#  'BAITING HOLW',
#  'BAITINGHOLLOW',
#  'BAKDWINSVILLE',
#  'BAKER',
#  'BAKER MILL',
#  'BAKER MILLS',
#  'BAKERS MILLS',
#  'BAKKSTON SPA',
#  'BALATIE',
#  'BALAVIA',
#  'BALD',
#  'BALDIN',
#  'BALDIN HARBOR',
#  'BALDINSVILLE',
#  'BALDSIN',
#  'BALDSINSVILLE',
#  'BALDSWINSVIL',
#  'BALDSWINSVILLE',
#  'BALDSWINVILLE',
#  'BALDSWINWILLE',
#  'BALDUIN',
#  'BALDW',
#  'BALDWAINSVILLE',
#  'BALDWI',
#  'BALDWIB',
#  'BALDWIIN',
#  'BALDWIINSVILLE',
#  'BALDWIN',
#  'BALDWIN HABOR',
#  'BALDWIN HAR',
#  'BALDWIN HARBOR',
#  'BALDWIN HARBOU',
#  'BALDWIN HARBR',
#  'BALDWIN HARNOR',
#  'BALDWIN HB',
#  'BALDWIN HBOR',
#  'BALDWIN HBR',
#  'BALDWIN HRB',
#  'BALDWIN HRBH',
#  'BALDWIN HRBR',
#  'BALDWIN HRDR',
#  'BALDWIN LANE',
#  'BALDWIN LI',
#  'BALDWIN PL',
#  'BALDWIN PLACE',
#  'BALDWIN PLACEW',
#  'BALDWIN WOODS',
#  'BALDWIND',
#  'BALDWINDSVILLE',
#  'BALDWING PLACE',
#  'BALDWINGVILLE',
#  'BALDWINHARBOR',
#  'BALDWINN',
#  'BALDWINN PLACE',
#  'BALDWINNSVILLE',
#  'BALDWINS',
#  'BALDWINSIILLE',
#  'BALDWINSILLE',
#  'BALDWINSIVLLE',
#  'BALDWINSSVILLE',
#  'BALDWINSVIILE',
#  'BALDWINSVIL',
#  'BALDWINSVILE',
#  'BALDWINSVILL',
#  'BALDWINSVILLE',
#  'BALDWINSVILLEN',
#  'BALDWINSVILLLE',
#  'BALDWINSVLLE',
#  'BALDWINSVLLLE',
#  'BALDWINSWILLE',
#  'BALDWINSWVILLE',
#  'BALDWINVILE',
#  'BALDWINVILLE',
#  'BALDWINVILLEQN',
#  'BALDWINVLLE',
#  'BALDWISNVILLE',
#  'BALDWISVILLE',
#  'BALDWN',
#  'BALDWN PL',
#  'BALDWNISVILLE',
#  'BALDWNSVILLE',
#  'BALDWW',
#  'BALEWINSVILLE',
#  'BALFWINSVILLE',
#  'BALL FAL',
#  'BALL LK',
#  'BALL SPA',
#  'BALLATON SPA',
#  'BALLISTON LAKE',
#  'BALLISTON SPA',
#  'BALLLSTON LAKE',
#  'BALLLSTON SPA',
#  'BALLMORE',
#  'BALLOSTON SPA',
#  'BALLPORT',
#  'BALLS SPA',
#  'BALLS SPAN',
#  'BALLSON LAKE',
#  'BALLSON SPA',
#  'BALLSOTN LAKE',
#  'BALLSPA SPA',
#  'BALLSRON SPA',
#  'BALLSSTON LK',
#  'BALLSSTON SPA',
#  'BALLSTEN SPA',
#  'BALLSTN SPA',
#  'BALLSTO LAKE',
#  'BALLSTO SPA',
#  'BALLSTOAN LAKE',
#  'BALLSTON',
#  'BALLSTON CAKE',
#  'BALLSTON CTR',
#  'BALLSTON DR',
#  'BALLSTON L',
#  'BALLSTON LA',
#  'BALLSTON LA KE',
#  'BALLSTON LAK E',
#  'BALLSTON LAKE',
#  'BALLSTON LANE',
#  'BALLSTON LK',
#  'BALLSTON LKAE',
#  'BALLSTON LKE',
#  'BALLSTON PARK',
#  'BALLSTON PLACE',
#  'BALLSTON SP',
#  'BALLSTON SP A',
#  'BALLSTON SPA',
#  'BALLSTON SPEA',
#  'BALLSTON STA',
#  'BALLSTON TRAIL',
#  'BALLSTON WAY',
#  'BALLSTONALEK',
#  'BALLSTONB SPA',
#  'BALLSTONE LAKE',
#  'BALLSTONE SPA',
#  'BALLSTONLAKE',
#  'BALLSTONM',
#  'BALLSTONS SPA',
#  'BALLSTONSPA',
#  'BALLSTSON SPA',
#  'BALLTON LAKE',
#  'BALLTON SPA',
#  'BALLWINSVILLE',
#  'BALMAT',
#  'BALMVILLE',
#  'BALO',
#  'BALOWIN',
#  'BALSDELL',
#  'BALSLTON SPA',
#  'BALSTON',
#  'BALSTON LAKE',
#  'BALSTON SPA',
#  'BALSWIN PL',
#  'BALSWINSVILLE',
#  'BALTON LANDING',
#  'BALTON LNDNG',
#  'BALUVELT',
#  'BALWDIN PLACE',
#  'BALWIN',
#  'BALWIN HARBOR',
#  'BALWIN PLACE',
#  'BALWINSVILLE',
#  'BALWSINSVILLE',
#  'BAMBRIDGE',
#  'BAMNS POINT',
#  'BAMUS POINT',
#  'BANGALL',
#  'BANGOR',
#  'BANKSVILLE',
#  'BANNOCKBURN',
#  'BANTON',
#  'BARBONIA',
#  'BARCALDINE DR',
#  'BARCLFF MNR',
#  'BARD',
#  'BARDONA',
#  'BARDONAIA',
#  'BARDONIA',
#  'BARDORIA',
#  'BARENVELD',
#  'BARISH',
#  'BARKER',
#  'BARLINGTON FLT',
#  'BARLONIA',
#  'BARMEVELD',
#  'BARN',
#  'BARNERVELD',
#  'BARNES CORNERS',
#  'BARNES CORS',
#  'BARNEVALD',
#  'BARNEVELD',
#  'BARNEVELD LN',
#  'BARNUM ISLAND',
#  'BARNUM ISLE',
#  'BARNVELD',
#  'BARRVILLE',
#  'BARRYTOWN',
#  'BARRYVILLE',
#  'BARRYVLE',
#  'BARTING HOLLOW',
#  'BARTON',
#  'BARTON NY',
#  'BASAM',
#  'BASDELL',
#  'BASHORE',
#  'BASHORENY',
#  'BASKIRK',
#  'BASLEY',
#  'BASLLSTON LAKE',
#  'BASOM',
#  'BASON',
#  'BASSLTON SPA',
#  'BASSPORT',
#  'BASYIDE',
#  'BASYSHORE',
#  'BAT SHORE',
#  'BATAIA',
#  'BATAIVA',
#  'BATANA',
#  'BATARIA',
#  'BATAVAI',
#  'BATAVI',
#  'BATAVIA',
#  'BATH',
#  'BATHA',
#  'BATHPAGE',
#  'BATING HOLLOW',
#  'BATIVIA',
#  'BATJ',
#  'BATOVIA',
#  'BATPORT',
#  ...]

# %%
ny_only.groupby('City')['Record Type'].count().reset_index().to_csv('../data/ny/ny_city_cleanup.csv')

# %%
nyc_zips = pd.read_csv('../data/ny/nyc_zips.txt')
nyc_zips_list = list(nyc_zips['ZIP Codes'].unique())

print(len(nyc_zips))
print(len(nyc_zips_list))
# Out:
# 178
# 178

# %%
nyc_veh = ny_veh.loc[ny_veh['Zip'].isin(nyc_zips_list)]

# %%
nyc_solid = nyc_veh.loc[(nyc_veh['reg_valid_year']> 2018)&(nyc_veh['reg_valid_date']< '2020-12-01')]
nyc_by_month = nyc_solid.groupby(['reg_valid_year','reg_valid_month'])['Record Type'].count().reset_index()

nyc_by_month['year_month'] = nyc_by_month['reg_valid_month'].astype(str) + '-' + nyc_by_month['reg_valid_year'].astype(str)

# %%
nyc_by_month.plot(x='year_month', y='Record Type')
# Out:
# <AxesSubplot:xlabel='year_month'>

# %%
nyc_by_month
# Out:
#     reg_valid_year  reg_valid_month  Record Type year_month
# 0             2019                1        46607     1-2019
# 1             2019                2        52338     2-2019
# 2             2019                3        69405     3-2019
# 3             2019                4        71214     4-2019
# 4             2019                5        76340     5-2019
# 5             2019                6        72644     6-2019
# 6             2019                7        78850     7-2019
# 7             2019                8        77216     8-2019
# 8             2019                9        73996     9-2019
# 9             2019               10        77297    10-2019
# 10            2019               11        69308    11-2019
# 11            2019               12        78654    12-2019
# 12            2020                1        93873     1-2020
# 13            2020                2       104971     2-2020
# 14            2020                3       103971     3-2020
# 15            2020                4        63897     4-2020
# 16            2020                5        96612     5-2020
# 17            2020                6       127820     6-2020
# 18            2020                7       146895     7-2020
# 19            2020                8       131010     8-2020
# 20            2020                9       138415     9-2020
# 21            2020               10       141315    10-2020
# 22            2020               11       113735    11-2020
# 23            2020               12          628    12-2020
# 24            2021                2           25     2-2021
